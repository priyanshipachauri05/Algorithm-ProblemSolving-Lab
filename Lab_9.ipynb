# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshipachauri05/Algorithm-ProblemSolving-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %%
def dijkstra(graph, start):
    distances = {}
    visited = []
    for node in graph:
        distances[node] = 10**8
    distances[start] = 0
    while len(visited) < len(graph):
        min_node = None
        min_distance = 10**8
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node
        visited.append(min_node)
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
    return distances

# %%
graph = {}
result=[]
choice=1
while choice==1:
  node=input("Enter a node:")
  choice2 =1
  while choice2==1:
    adj={}
    neigh=input("Enter the adjacent node:")
    weight=int(input("Enter the weight of the edge"))
    adj[neigh]=weight
    choice2=int(input("Do you want to continue?"))
  graph[node]=adj
  choice=int(input("Do you want to continude adding nodes?"))
starting_node=input("Enter the starting node:")
result=dijkstra(graph,starting_node)
for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Enter a node:'A'
# Enter the adjacent node:'B'
# Enter the weight of the edge1
# Do you want to continue?1
# Enter the adjacent node:'C'
# Enter the weight of the edge5
# Do you want to continue?2
# Do you want to continude adding nodes?1
# Enter a node:'B'
# Enter the adjacent node:'C'
# Enter the weight of the edge2
# Do you want to continue?2
# Do you want to continude adding nodes?1
# Enter a node:'C'
# Enter the adjacent node:'D'
# Enter the weight of the edge3
# Do you want to continue?2
# Do you want to continude adding nodes?1
# Enter a node:'D'
# Enter the adjacent node:'A'
# Enter the weight of the edge4
# Do you want to continue?1
# Enter the adjacent node:'B'
# Enter the weight of the edge6
# Do you want to continue?2
# Do you want to continude adding nodes?2
# Enter the starting node:'A'
# Distance from A to 'A' = 0
# Distance from A to 'B' = 14
# Distance from A to 'C' = 5
# Distance from A to 'D' = 8

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
